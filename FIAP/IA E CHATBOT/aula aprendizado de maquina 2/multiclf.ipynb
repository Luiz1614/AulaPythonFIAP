# %% [markdown]
# # Aprendizado de maquina supervisionado para classificação
#
# Quando a máquina usa dados para aprender a resonver um problema de forma automatizada.
# A máquina pode aprender a classificar informações (atribuir categorias pre definidas)
# A supervisão vem de fornecer a resposta certa para máquina aprender.
#
# > O ML é a tarefa de receber uma entrada $\mathbf{X}$ e uma saída esperada $\mathbf{y}$ (a supervisão), e tenta encontrar uma função $f$ que mapeia  $\mathbf{X} \rightarrow \mathbf{y}$. No futuro, podemos usar $f$ para prever (estimar) $\mathbf{\hat{y}}$ novas saídas para novas entradas.

# %%
# !pip install --quiet matplotlib seaborn pandas scikit-learn

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Blood_samples_dataset_balanced_MODIFICADO.csv')
df.sample(5)
# Out:
#       Unnamed: 0   Glucose  Cholesterol  Hemoglobin  Platelets  \
# 2239        2239  0.161063     0.412685    0.530557   0.411971
# 1420        1420  0.543341     0.723665    0.779163   0.760858
# 68            68  0.621955     0.414555    0.582661   0.469969
# 1014        1014  0.455748     0.481771    0.861509   0.804846
# 222          222  0.322055     0.663170    0.369970   0.813487
#
#       White Blood Cells  Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 2239           0.892344         0.593168    0.763690                 0.454253
# 1420           0.188187         0.462340    0.779290                 0.496436
# 68             0.948275         0.482522    1.037687                 0.439678
# 1014           0.974096         0.646216    0.606034                 0.319914
# 222            0.832422         0.121064    0.401978                 0.832681
#
#       Mean Corpuscular Hemoglobin  ...     HbA1c  LDL Cholesterol  \
# ...

# %%
df.shape
# Out:
# (768, 9)

# %%
df = df.drop("Unnamed: 0", axis=1)

# %%
df.columns
# Out:
# Index(['Glucose', 'Cholesterol', 'Hemoglobin', 'Platelets',
#        'White Blood Cells', 'Red Blood Cells', 'Hematocrit',
#        'Mean Corpuscular Volume', 'Mean Corpuscular Hemoglobin',
#        'Mean Corpuscular Hemoglobin Concentration', 'Insulin', 'BMI',
#        'Systolic Blood Pressure', 'Diastolic Blood Pressure', 'Triglycerides',
#        'HbA1c', 'LDL Cholesterol', 'HDL Cholesterol', 'ALT', 'AST',
#        'Heart Rate', 'Creatinine', 'Troponin', 'C-reactive Protein',
#        'Disease'],
#       dtype='object')

# %%
for col in df.columns:
    print(col)
    sns.catplot(x="Disease", kind="box", y=col, data=df, hue="Disease")

    plt.show()
# Out:
# Glucose
# Cholesterol
# Hemoglobin
# Platelets
# White Blood Cells
# Red Blood Cells
# Hematocrit
# Mean Corpuscular Volume
# Mean Corpuscular Hemoglobin
# Mean Corpuscular Hemoglobin Concentration
# Insulin
# BMI
# Systolic Blood Pressure
# Diastolic Blood Pressure
# Triglycerides
# HbA1c
# LDL Cholesterol
# HDL Cholesterol
# ALT
# AST
# Heart Rate
# Creatinine
# Troponin
# C-reactive Protein
# Disease

# %%
X = df.drop("Disease", axis=1)
y = df["Disease"]

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
medico = DecisionTreeClassifier()#clf
medico.fit(X, Y)
# Out:
# DecisionTreeClassifier()

# %%
plot_tree(medico);

# %%
from sklearn.metrics import accuracy_score

# %%
paciente_aleatorio = X.sample(3, random_state=42)
paciente_aleatorio
# Out:
#        Glucose  Cholesterol  Hemoglobin  Platelets  White Blood Cells  \
# 2236  0.166203     0.715004    0.718211   1.038445           0.791181
# 668   0.563720     0.468631    0.390634   0.580349           1.159950
# 2005  0.576591     0.864063    0.571008   1.153372           0.526875
#
#       Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 2236         0.818299    0.262325                 1.033515
# 668          0.299237    0.985401                 0.344824
# 2005         0.653220    0.942053                 1.041122
#
#       Mean Corpuscular Hemoglobin  Mean Corpuscular Hemoglobin Concentration  \
# 2236                     0.396963                                   0.057835
# 668                      0.278967                                   0.844606
# 2005                     0.210588                                   1.227110
#
#       ...  Triglycerides     HbA1c  LDL Cholesterol  HDL Cholesterol  \
# ...

# %%
medico.predict(paciente_aleatorio)
# Out:
# array(['Anemia', 'Healthy', 'Diabetes'], dtype=object)

# %%
accuracy_score(y, medico.predict(X))
# Out:
# 1.0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
medico2 = DecisionTreeClassifier()
medico2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print(accuracy_score(y_test, medico2.predict(X_test)))
print(accuracy_score(y_train, medico2.predict(X_train)))
# Out:
# 0.8930412371134021
# 1.0
